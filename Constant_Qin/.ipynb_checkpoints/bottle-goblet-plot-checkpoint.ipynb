# %%
import FR_mainCode_plus as fr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#resdic = fr.calc_sim(r1=2,r2=4,shape='nodes',dh_below=10)
reslist_bottle = [] # Create empty list
for r1 in [5,7.5,10,12.5,15]:
    resdic = fr.calc_sim(shape = 'nodes',r1=r1,r2=10)
    reslist_bottle.append(resdic) # add dictionnary to the bottom of the list
fr.plot_FR_JGR(reslist_bottle)

# %%
#resdic = fr.calc_sim(r1=2,r2=4,shape='nodes',dh_below=10)
reslist_bottle = [] # Create empty list
for r2 in [5,7.5,10,12.5,15]:
    resdic = fr.calc_sim(shape = 'nodes',r1=10,r2=r2)
    reslist_bottle.append(resdic) # add dictionnary to the bottom of the list
fr.plot_FR_JGR(reslist_bottle)
